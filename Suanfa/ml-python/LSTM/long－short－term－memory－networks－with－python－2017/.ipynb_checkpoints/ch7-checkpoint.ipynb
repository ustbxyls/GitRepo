# %%
# Example of one output for whole sequence
from keras.models import Sequential
from keras.layers import LSTM
from numpy import array

# %%
# define model where LSTM is alse output layer
model = Sequential()
model.add(LSTM(1, input_shape=(3,1)))
model.compile(optimizer='adam', loss='mse')

# %%
#input time steps
data = array([0.1, 0.2, 0.3]).reshape((1,3,1))
# make and show prediction
print(model.predict(data))
# Out:
# [[0.06412907]]

# %%
# Example of one output for each input time step
# define model where LSTM is alse output layer
model = Sequential()
model.add(LSTM(1, return_sequences=True, input_shape=(3,1)))
model.compile(optimizer='adam', loss='mse')

# %%
#input time steps
data = array([0.1, 0.2, 0.3]).reshape((1,3,1))
# make and show prediction
print(model.predict(data))
# Out:
# [[[-0.00454963]
#   [-0.01237507]
#   [-0.02258901]]]

# %%
# 7.2.1
from math import sin
from math import pi
from matplotlib import pyplot

# %%
# create sequence
length = 100
freq = 5
sequence = [sin(2 * pi * freq * (i/length)) for i in range(length)]

# %%
# plot sequence
pyplot.plot(sequence)
pyplot.show()

# %%
# 7.2.2 Damped Sine Wave
from math import exp

# create sequence
length = 100
freq = 10
decay = 0.05
sequence = [0.5 + 0.5 * sin(2 * pi * i/freq) * exp(-decay * i) for i in range(length)]

# %%
# plot sequence
pyplot.plot(sequence)
pyplot.show()

# %%
# generate dampled sine wave in [0,1]
def generate_sequence(length, period, decay):
    return [0.5 + 0.5 * sin(2 * pi * i/freq) * exp(-decay * i) for i in range(length)]

# %%
from random import random
from random import randint
from random import uniform

# generate input and output pairs of damped sine waves
def generate_examples(length, n_patterns, output):
    X, y = list(), list()
    for _ in range(n_patterns):
        p = randint(10, 20)
        d = uniform(0.01, 0.1)
        sequence = generate_sequence(length + output, p, d)
        X.append(sequence[:-output])
        y.append(sequence[-output:])
    X = array(X).reshape(n_patterns, length, 1)
    y = array(y).reshape(n_patterns, output)
    return X, y

# %%
# test problem generateion
X,y = generate_examples(20, 5, 5)
for i in range(len(X)):
    pyplot.plot([x for x in X[i, :, 0]] + [x for x in y[i]], '-o')
pyplot.show()

# %%
from keras.layers import Dense
# configure problem
length = 50
output = 5
# define model
model = Sequential()
model.add(LSTM(20, return_sequences=True, input_shape=(length, 1)))
model.add(LSTM(20))
model.add(Dense(output))
model.compile(loss='mae', optimizer='adam')
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 50, 20)            1760
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 20)                3280
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 105
# =================================================================
# Total params: 5,145
# Trainable params: 5,145
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# fit model
X,y = generate_examples(length, 10000, output)
model.fit(X,y,batch_size=10, epochs=1)
# Out:
# Epoch 1/1
# 10000/10000 [==============================] - 43s 4ms/step - loss: 0.0316

# %%
# evaluate model
X,y = generate_examples(length,1000, output)
loss = model.evaluate(X, y, verbose=0)
print('MAE: %f' % loss)
# Out:
# MAE: 0.004201

# %%
# prediction on new data
X, y = generate_examples(length, 1, output)
yhat = model.predict(X, verbose=0)
pyplot.plot(y[0], label='y')
pyplot.plot(yhat[0], label='yhat')
pyplot.legend()
pyplot.show()
